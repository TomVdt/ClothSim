# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

# %%
# Run tests
# !make tests
# !bin/tests/testIntegrator1
# !bin/tests/testIntegrator2
# !bin/tests/testIntegrator3
# !bin/tests/testIntegrator4
# Out:
# [MAKE] Creating build directories
# [LD] Linking testVector3d
# [LD] Linking testMasse
# [LD] Linking testSpring
# [LD] Linking testIntegrator1
# [LD] Linking testIntegrator2
# [LD] Linking testIntegrator3
# [LD] Linking testIntegrator4
# [LD] Linking testCloth1
# [LD] Linking testCloth2
# [LD] Linking testSystem
# [MAKE] Build complete for tests

# %%
data = np.loadtxt("testIntegrator1.txt", delimiter=",")

fig, ax = plt.subplots(nrows=2, ncols=2)

x = np.linspace(0, 0.7, 50)
ax[0, 0].set_title("Chute libre, v0!=0")
ax[0, 0].plot(x, 1. + (2.-9.81*0.01/2.)*x - (9.81/2.)*x*x)
ax[0, 0].scatter(data[:,0], data[:,1])
ax[0, 1].set_title("Chute verticale, v0=0")
ax[0, 1].scatter(data[:,3], data[:,4])
ax[1, 0].set_title("Chute verticale, v0=(0,2,0)")
ax[1, 0].scatter(data[:,6], data[:,7])
ax[1, 1].set_title("Chute libre, λ=0.3")
ax[1, 1].scatter(data[:,9], data[:,10])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

data = np.loadtxt("testIntegrator2.txt", delimiter=",")

fig, ax = plt.subplots()

ax.plot(data[:,0], data[:,2])
ax.plot(data[:,3], data[:,5])
ax.plot(data[:,6], data[:,8])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

data = np.loadtxt("testIntegrator3.txt", delimiter=",")

fig, ax = plt.subplots()

ax.scatter(data[:,0], data[:,1])
ax.scatter(data[:,3], data[:,4])
ax.scatter(data[:,6], data[:,7])

plt.show()
# Out:
# No such comm: c865b2088956434eb07e24a13484f109
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

data = np.loadtxt("testIntegrator4.txt", delimiter=",")

fig, ax = plt.subplots()
ax = plt.axes(projection="3d")

ax.scatter3D(data[:,0], data[:,2], data[:,1])
ax.scatter3D(data[:,3], data[:,5], data[:,4])
ax.set_xlabel("x")
ax.set_ylabel("z (depth)")
ax.set_zlabel("y (height)")

plt.show()
# Out:
# No such comm: e84e8f3050e64cabb2c4e0056b1578d3
# No such comm: e84e8f3050e64cabb2c4e0056b1578d3
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# No such comm: f9d4b244a26f47bda3ce1860b0692a0f

# %%
data = np.loadtxt("testConstraint2.txt", delimiter=",")

fig, ax = plt.subplots()
ax = plt.axes(projection="3d")

ax.scatter3D(data[::5,0], data[::5,2], data[::5,1])
ax.set_xlabel("x")
ax.set_ylabel("z (depth)")
ax.set_zlabel("y (height)")

plt.show()

data = np.loadtxt("/tmp/contraintes.txt", delimiter=" ", comments="#")

fig, ax = plt.subplots()
ax = plt.axes(projection="3d")

ax.scatter3D(data[::5,0], data[::5,1], data[::5,2])
ax.set_xlabel("x")
ax.set_ylabel("z (depth)")
ax.set_zlabel("y (height)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = np.loadtxt("/tmp/contraintes.txt", delimiter=" ", comments="#")

fig, ax = plt.subplots()
ax = plt.axes(projection="3d")

ax.scatter3D(data[::5,0], data[::5,1], data[::5,2])
ax.set_xlabel("x")
ax.set_ylabel("z (depth)")
ax.set_zlabel("y (height)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

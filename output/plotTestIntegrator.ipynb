# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

# %%
# Run tests
# !make run_tests
# Out:
# [MAKE] Creating build directories
# [MAKE] Build complete for tests
# [TEST] Running bin/tests/testCloth1
# [TEST] Running bin/tests/testCloth2
# [TEST] Running bin/tests/testConstraint1
# [TEST] Running bin/tests/testConstraint2
# [TEST] Running bin/tests/testIntegrator1
# [TEST] Running bin/tests/testIntegrator2
# [TEST] Running bin/tests/testIntegrator3
# [TEST] Running bin/tests/testIntegrator4
# [TEST] Running bin/tests/testMasse
# ===== Test affichage =====
# Masse 0x7ffdcb7ae800 {masse: 12.2, lambda: 0, position: (0 0 0), vitesse: (0 0 0), force: (0 -119.682 0), ressorts: []}
# Masse 0x7ffdcb7ae760 {masse: 4.5, lambda: 2.3, position: (1 1 1), vitesse: (2 2 2), force: (0 -44.145 0), ressorts: [0x7ffdcb7ae700, 0x7ffdcb7ae730]}
#
# ===== Tests getters =====
# getter masse: PASS
# getter lambda: PASS
# getter position: PASS
# getter vitesse: PASS
# getter force: PASS
#
# ===== Tests setters =====
# setter position: PASS
# setter vitesse: PASS
#
# ===== accélération et force =====
# acceleration: PASS
# add force: PASS
# maj force: PASS
#
# ===== connections aux ressorts =====
# connections: PASS
# connections: PASS
# affiche : Masse 0x7ffdcb7ae800 {masse: 12.2, lambda: 0, position: (3 3 3), vitesse: (1 2 3), force: (0 -119.682 0), ressorts: [0x7ffdcb7ae700, 0x7ffdcb7ae730]}
# devait afficher pour les ressorts: 0x7ffdcb7ae700 et 0x7ffdcb7ae730
# connections: PASS
# connections: PASS
# affiche : Masse 0x7ffdcb7ae800 {masse: 12.2, lambda: 0, position: (3 3 3), vitesse: (1 2 3), force: (0 -119.682 0), ressorts: [0x7ffdcb7ae730]}
# devait afficher pour les ressorts: 0x7ffdcb7ae730
# connections: PASS
# connections: PASS
# affiche: Masse 0x7ffdcb7ae760 {masse: 4.5, lambda: 2.3, position: (1 1 1), vitesse: (2 2 2), force: (-4.6 -48.745 -4.6), ressorts: []}
# ne devait rien afficher pour les ressorts
# [TEST] Running bin/tests/testSpring
# ==== Pre-connection ====
# Spring 1: Spring 0x7ffcde94e8f0 {
#   k: 1,
#   l0: 1,
#   masse 1: Masse 0x7ffcde94edf8 {masse: 1, lambda: 0, position: (0 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: []},
#   masse 2: Masse 0x7ffcde94ed60 {masse: 1, lambda: 0, position: (1 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: []}
# }
#
# ==== Post-connection ====
# Spring 1: Spring 0x7ffcde94e8f0 {
#   k: 1,
#   l0: 1,
#   masse 1: Masse 0x7ffcde94edf8 {masse: 1, lambda: 0, position: (0 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x7ffcde94e8f0]},
#   masse 2: Masse 0x7ffcde94ed60 {masse: 1, lambda: 0, position: (1 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x7ffcde94e8f0]}
# }
#
# ==== Forces ressorts ====
# Ressort 1 stable: PASS
# Ressort 1 stable: PASS
# Ressort 2 compressé: PASS
# Ressort 2 compressé: PASS
# Ressort 3 étendu: PASS
# Ressort 3 étendu: PASS
# Ressort 4 diagonal: PASS
# Ressort 4 diagonal: PASS
# Surcompression: PASS
#
# ==== Springs malformés ====
#
# 2 masses identiques: PASS
# Ressort correct: PASS
#
# ==== Changement des masses (pos, vel, etc) ====
# Avant changement Spring 7: Spring 0x7ffcde94e890 {
#   k: 1,
#   l0: 1,
#   masse 1: Masse 0x7ffcde94eb20 {masse: 1, lambda: 0, position: (0 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x7ffcde94e890]},
#   masse 2: Masse 0x7ffcde94ecc0 {masse: 2, lambda: 0, position: (0 0 0), vitesse: (0 0 0), force: (0 -19.62 0), ressorts: [0x7ffcde94e890]}
# }
# Après changement Spring 7: Spring 0x7ffcde94e890 {
#   k: 1,
#   l0: 1,
#   masse 1: Masse 0x7ffcde94eb20 {masse: 1, lambda: 0, position: (69 42 6), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x7ffcde94e890]},
#   masse 2: Masse 0x7ffcde94ecc0 {masse: 2, lambda: 0, position: (0 0 0), vitesse: (420 420 420), force: (0 -19.62 0), ressorts: [0x7ffcde94e890]}
# }
#
# ==== Methodes d'aide ====
# Connection complete fausse: PASS
# Connection complete: PASS
# [TEST] Running bin/tests/testSystem
# System 0x7ffcb7e45150 {
#   tissus: [
#     Cloth 0x133a9b0 {
#       masses (3): [
#         Masse 0x133a9f0 {masse: 1, lambda: 0.3, position: (0 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133ac40, 0x133aca0]}
#         Masse 0x133aab0 {masse: 1, lambda: 0.3, position: (2 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133ac40, 0x133ad20]}
#         Masse 0x133ab70 {masse: 1, lambda: 0.3, position: (0 0 2), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133aca0, 0x133ad20]}
#       ],
#       ressorts (3): [
#         Spring 0x133ac40 {
#           k: 9,
#           l0: 1.5,
#           masse 1: Masse 0x133a9f0 {masse: 1, lambda: 0.3, position: (0 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133ac40, 0x133aca0]},
#           masse 2: Masse 0x133aab0 {masse: 1, lambda: 0.3, position: (2 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133ac40, 0x133ad20]}
#         }
#         Spring 0x133aca0 {
#           k: 1.9,
#           l0: 1.75,
#           masse 1: Masse 0x133a9f0 {masse: 1, lambda: 0.3, position: (0 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133ac40, 0x133aca0]},
#           masse 2: Masse 0x133ab70 {masse: 1, lambda: 0.3, position: (0 0 2), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133aca0, 0x133ad20]}
#         }
#         Spring 0x133ad20 {
#           k: 5.5,
#           l0: 1.25,
#           masse 1: Masse 0x133aab0 {masse: 1, lambda: 0.3, position: (2 0 0), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133ac40, 0x133ad20]},
#           masse 2: Masse 0x133ab70 {masse: 1, lambda: 0.3, position: (0 0 2), vitesse: (0 0 0), force: (0 -9.81 0), ressorts: [0x133aca0, 0x133ad20]}
#         }
#       ]
#     }
#   ],
#   masses: 3,
#   ressorts: 3
# }
# [TEST] Running bin/tests/testVector3d
# ==== Affichage ====
# Vec1: (1 2 -0.1)
#
# ==== Sanity check ====
# Coords: PASS
# Coords: PASS
# Coords: PASS
# Setter: PASS
# Setter: PASS
# Setter: PASS
# Constructeur 1: PASS
# Constructeur 2: PASS
# Copie: PASS
#
# ==== Interface ====
# Norme: PASS
# Norme2: PASS
# Norme2: PASS
# Unitaire: PASS
# Unitaire en-place: PASS
# Scalaire: PASS
# Scalaire commutatif: PASS
# Vectoriel: PASS
# Vectoriel anticommutatif: PASS
#
# ==== Opérateurs ====
# Addition: PASS
# Addition commutative: PASS
# Addition zero: PASS
# Addition oppose: PASS
# Soustraction: PASS
# Soustraction self: PASS
# Oppose: PASS
# Multiplication entier: PASS
# Multiplication: PASS
# Multiplication commutative: PASS
# Division entier: PASS
# Division: PASS
# Scalaire: PASS
# Vectoriel: PASS
# Unitaire: PASS
# Egalite: PASS
# Egalite: PASS
# Egalite proche: PASS
# Different: PASS
# Different: PASS
#
# ==== Opérateurs en place ====
# +=: PASS
# *=: PASS
# /=: PASS
# -=: PASS

# %%
data = np.loadtxt("testIntegrator1.txt", delimiter=",")

fig, ax = plt.subplots(nrows=2, ncols=2)

x = np.linspace(0, 0.7, 50)
ax[0, 0].set_title("Chute libre, v0!=0")
ax[0, 0].plot(x, 1. + (2.-9.81*0.01/2.)*x - (9.81/2.)*x*x)
ax[0, 0].scatter(data[:,0], data[:,1])
ax[0, 1].set_title("Chute verticale, v0=0")
ax[0, 1].scatter(data[:,3], data[:,4])
ax[1, 0].set_title("Chute verticale, v0=(0,2,0)")
ax[1, 0].scatter(data[:,6], data[:,7])
ax[1, 1].set_title("Chute libre, λ=0.3")
ax[1, 1].scatter(data[:,9], data[:,10])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

data = np.loadtxt("testIntegrator2.txt", delimiter=",")

fig, ax = plt.subplots()

ax.plot(data[:,0], data[:,2])
ax.plot(data[:,3], data[:,5])
ax.plot(data[:,6], data[:,8])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

data = np.loadtxt("testIntegrator3.txt", delimiter=",")

fig, ax = plt.subplots()

ax.scatter(data[:,0], data[:,1])
ax.scatter(data[:,3], data[:,4])
ax.scatter(data[:,6], data[:,7])

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

data = np.loadtxt("testIntegrator4.txt", delimiter=",")

fig, ax = plt.subplots()
ax = plt.axes(projection="3d")

ax.scatter3D(data[:,0], data[:,2], data[:,1])
ax.scatter3D(data[:,3], data[:,5], data[:,4])
ax.set_xlabel("x")
ax.set_ylabel("z (depth)")
ax.set_zlabel("y (height)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = np.loadtxt("testConstraint1.txt", delimiter=",")

fig, ax = plt.subplots()
ax = plt.axes(projection="3d")

ax.scatter3D(data[::5,0], data[::5,2], data[::5,1])
ax.set_xlabel("x")
ax.set_ylabel("z (depth)")
ax.set_zlabel("y (height)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = np.loadtxt("testConstraint2.txt", delimiter=",")

fig, ax = plt.subplots()
ax = plt.axes(projection="3d")

ax.scatter3D(data[::5,0], data[::5,2], data[::5,1])
ax.set_xlabel("x")
ax.set_ylabel("z (depth)")
ax.set_zlabel("y (height)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data = np.loadtxt("contraintesValeursReference.txt", delimiter=" ", comments="#")

fig, ax = plt.subplots()
ax = plt.axes(projection="3d")

ax.scatter3D(data[::5,0], data[::5,1], data[::5,2])
ax.set_xlabel("x")
ax.set_ylabel("z (depth)")
ax.set_zlabel("y (height)")

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
